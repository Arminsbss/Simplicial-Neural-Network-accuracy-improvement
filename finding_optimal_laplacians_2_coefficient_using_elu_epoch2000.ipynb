# %% [markdown]
# <a href="https://colab.research.google.com/github/Arminsbss/Simplicial-Neural-Network/blob/Arminsbss-learning-rate-and-epochs/finding_optimal_laplacians_2_coefficient_using_elu_epoch2000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/stefaniaebli/simplicial_neural_networks.git
# Out:
# Cloning into 'simplicial_neural_networks'...
# remote: Enumerating objects: 339, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 339 (delta 50), reused 48 (delta 48), pack-reused 280
# Receiving objects: 100% (339/339), 2.42 MiB | 9.65 MiB/s, done.
# Resolving deltas: 100% (189/189), done.

# %%
import random
import os
import numpy as np
from sklearn.metrics import accuracy_score
import math

Iteration=1
random_numbers=[]
accuracies_for_0_laplacian=[]
accuracies_for_1_laplacian=[]
accuracies_for_2_laplacian=[]

while Iteration<=1:
  # %cd /content/simplicial_neural_networks/data/s2_3_collaboration_complex
  laplacians = np.load('150250_laplacians.npy',allow_pickle=True)

  random_number = random.random()
  random_numbers.append(random_number)

  for i in range(4697):
    if laplacians[2].data[i]<=0:
      print(laplacians[2].data[i],end='->')
      laplacians[2].data[i] = math.exp(laplacians[2].data[i])-1
      print(laplacians[2].data[i])
  # for i in range(3285):
  #   laplacians[2].data[(laplacians[2].row==i) & (laplacians[2].col==i)]+=1

  # %cd /content/simplicial_neural_networks/data/s2_3_collaboration_complex
  np.save('150250_laplacians.npy', laplacians)

  # %cd /content/simplicial_neural_networks
  # !python ./experiments/impute_citations.py ./data/s2_3_collaboration_complex ./experiments/output 150250 30

  #calculating accuracy for the 0-laplacian
  # %cd /content/simplicial_neural_networks/experiments/output

  folder_path = '/content/simplicial_neural_networks/experiments/output'

  files = os.listdir(folder_path)
  files.sort()

  prediction = []
  actual = []

  for filename in os.listdir('.'):
    if filename.startswith('prediction') and filename.endswith('0.txt'):
      with open(filename, 'r') as f:
          numbers_str = f.read()
      numbers_list = numbers_str.split()
      numbers_int = list(map(float, numbers_list))
      prediction += numbers_int
    elif filename.startswith('actual') and filename.endswith('0.txt'):
      with open(filename, 'r') as f:
          numbers_str = f.read()
      numbers_list = numbers_str.split()
      numbers_int = list(map(float, numbers_list))
      actual += numbers_int
  prediction = [round(x, 0) for x in prediction]
  actual = [round(x, 0) for x in actual]

  accuracy = accuracy_score(actual, prediction)
  accuracies_for_0_laplacian.append(accuracy)
  print("We set this random number: ",random_number)
  print(f'Accuracy for 0-laplacian: {accuracy}')

  #calculating accuracy for the 1-laplacian
  prediction = []
  actual = []

  for filename in os.listdir('.'):
      if filename.startswith('prediction') and filename.endswith('1.txt'):
          with open(filename, 'r') as f:
              numbers_str = f.read()
          numbers_list = numbers_str.split()
          numbers_int = list(map(float, numbers_list))
          prediction += numbers_int
      elif filename.startswith('actual') and filename.endswith('1.txt'):
          with open(filename, 'r') as f:
              numbers_str = f.read()
          numbers_list = numbers_str.split()
          numbers_int = list(map(float, numbers_list))
          actual += numbers_int
  prediction = [round(x, 0) for x in prediction]
  actual = [round(x, 0) for x in actual]

  accuracy = accuracy_score(actual, prediction)
  accuracies_for_1_laplacian.append(accuracy)
  print(f'Accuracy for 1-laplacian: {accuracy}')

  #calculating accuracy for the 2-laplacian
  prediction = []
  actual = []

  for filename in os.listdir('.'):
      if filename.startswith('prediction') and filename.endswith('2.txt'):
          with open(filename, 'r') as f:
              numbers_str = f.read()
          numbers_list = numbers_str.split()
          numbers_int = list(map(float, numbers_list))
          prediction += numbers_int
      elif filename.startswith('actual') and filename.endswith('2.txt'):
          with open(filename, 'r') as f:
              numbers_str = f.read()
          numbers_list = numbers_str.split()
          numbers_int = list(map(float, numbers_list))
          actual += numbers_int
  prediction = [round(x, 0) for x in prediction]
  actual = [round(x, 0) for x in actual]

  accuracy = accuracy_score(actual, prediction)
  accuracies_for_2_laplacian.append(accuracy)
  print(f'Accuracy for 2-laplacian: {accuracy}')

  max_accuracy0 = max(accuracies_for_0_laplacian)
  max_index0 = accuracies_for_0_laplacian.index(max_accuracy0)
  print(f"The maximum accuracy for 0 laplacian is: {max_accuracy0} and its index is: {max_index0} with coefficient {random_numbers[max_index0]}")

  max_accuracy1 = max(accuracies_for_1_laplacian)
  max_index1 = accuracies_for_1_laplacian.index(max_accuracy1)
  print(f"The maximum accuracy for 1 laplacian is: {max_accuracy1} and its index is: {max_index1} with coefficient {random_numbers[max_index1]}")

  max_accuracy2 = max(accuracies_for_2_laplacian)
  max_index2 = accuracies_for_2_laplacian.index(max_accuracy2)
  print(f"The maximum accuracy for 2 laplacian is: {max_accuracy2} and its index is: {max_index2} with coefficient {random_numbers[max_index2]}")

  Iteration+=1
# Out:
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# -1.0->-0.63212055
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5385466333562293
# Accuracy for 0-laplacian: 0.6680589430894309
# Accuracy for 1-laplacian: 0.6876905916585839
# Accuracy for 2-laplacian: 0.6995324053936494
# The maximum accuracy for 0 laplacian is: 0.6680589430894309 and its index is: 0 with coefficient 0.5385466333562293
# The maximum accuracy for 1 laplacian is: 0.6876905916585839 and its index is: 0 with coefficient 0.5385466333562293
# The maximum accuracy for 2 laplacian is: 0.6995324053936494 and its index is: 0 with coefficient 0.5385466333562293

# %%
# 0-laplacian accuracies
for i in range(len(accuracies_for_0_laplacian)):
  print("0-laplacian accuracy: ",accuracies_for_0_laplacian[i],"for random number: ",random_numbers[i])
# Out:
# 0-laplacian accuracy:  0.6680589430894309 for random number:  0.5385466333562293

# %%
# 1-laplacian accuracies
for i in range(len(accuracies_for_1_laplacian)):
  print("1-laplacian accuracy: ",accuracies_for_1_laplacian[i],"for random number: ",random_numbers[i])
# Out:
# 1-laplacian accuracy:  0.6876905916585839 for random number:  0.5385466333562293

# %%
# 2-laplacian accuracies
for i in range(len(accuracies_for_2_laplacian)):
  print("2-laplacian accuracy: ",accuracies_for_2_laplacian[i],"for random number: ",random_numbers[i])
# Out:
# 2-laplacian accuracy:  0.6995324053936494 for random number:  0.5385466333562293

# %%
print("Max accuracy we got: ",max_accuracy0,max_accuracy1,max_accuracy2)
# Out:
# Max accuracy we got:  0.6454959349593496 0.6508690591658584 0.7004306220095694
