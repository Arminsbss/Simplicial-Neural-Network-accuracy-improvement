# %% [markdown]
# <a href="https://colab.research.google.com/github/Arminsbss/Simplicial-Neural-Network/blob/main/finding_optimal_laplacians_1_coefficient_using_randomization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/stefaniaebli/simplicial_neural_networks.git
# Out:
# Cloning into 'simplicial_neural_networks'...
# remote: Enumerating objects: 339, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 339 (delta 50), reused 48 (delta 48), pack-reused 280
# Receiving objects: 100% (339/339), 2.42 MiB | 11.75 MiB/s, done.
# Resolving deltas: 100% (189/189), done.

# %%
import random
import os
import numpy as np
from sklearn.metrics import accuracy_score

Iteration=1
random_numbers=[]
accuracies_for_0_laplacian=[]
accuracies_for_1_laplacian=[]
accuracies_for_2_laplacian=[]

while Iteration<=25:
  # %cd /content/simplicial_neural_networks/data/s2_3_collaboration_complex
  laplacians = np.load('150250_laplacians.npy',allow_pickle=True)

  random_number = random.random()
  random_numbers.append(random_number)

  for i in range(25466):
    laplacians[1].data[i] *= random_number
  for i in range(1474):
    laplacians[1].data[(laplacians[1].row==i) & (laplacians[1].col==i)]+=1

  # %cd /content/simplicial_neural_networks/data/s2_3_collaboration_complex
  np.save('150250_laplacians.npy', laplacians)

  # %cd /content/simplicial_neural_networks
  # !python ./experiments/impute_citations.py ./data/s2_3_collaboration_complex ./experiments/output 150250 30

  #calculating accuracy for the 0-laplacian
  # %cd /content/simplicial_neural_networks/experiments/output

  folder_path = '/content/simplicial_neural_networks/experiments/output'

  files = os.listdir(folder_path)
  files.sort()

  prediction = []
  actual = []

  for filename in os.listdir('.'):
    if filename.startswith('prediction') and filename.endswith('0.txt'):
      with open(filename, 'r') as f:
          numbers_str = f.read()
      numbers_list = numbers_str.split()
      numbers_int = list(map(float, numbers_list))
      prediction += numbers_int
    elif filename.startswith('actual') and filename.endswith('0.txt'):
      with open(filename, 'r') as f:
          numbers_str = f.read()
      numbers_list = numbers_str.split()
      numbers_int = list(map(float, numbers_list))
      actual += numbers_int
  prediction = [round(x, 0) for x in prediction]
  actual = [round(x, 0) for x in actual]

  accuracy = accuracy_score(actual, prediction)
  accuracies_for_0_laplacian.append(accuracy)
  print("We set this random number: ",random_number)
  print(f'Accuracy for 0-laplacian: {accuracy}')

  #calculating accuracy for the 1-laplacian
  prediction = []
  actual = []

  for filename in os.listdir('.'):
      if filename.startswith('prediction') and filename.endswith('1.txt'):
          with open(filename, 'r') as f:
              numbers_str = f.read()
          numbers_list = numbers_str.split()
          numbers_int = list(map(float, numbers_list))
          prediction += numbers_int
      elif filename.startswith('actual') and filename.endswith('1.txt'):
          with open(filename, 'r') as f:
              numbers_str = f.read()
          numbers_list = numbers_str.split()
          numbers_int = list(map(float, numbers_list))
          actual += numbers_int
  prediction = [round(x, 0) for x in prediction]
  actual = [round(x, 0) for x in actual]

  accuracy = accuracy_score(actual, prediction)
  accuracies_for_1_laplacian.append(accuracy)
  print(f'Accuracy for 1-laplacian: {accuracy}')

  #calculating accuracy for the 2-laplacian
  prediction = []
  actual = []

  for filename in os.listdir('.'):
      if filename.startswith('prediction') and filename.endswith('2.txt'):
          with open(filename, 'r') as f:
              numbers_str = f.read()
          numbers_list = numbers_str.split()
          numbers_int = list(map(float, numbers_list))
          prediction += numbers_int
      elif filename.startswith('actual') and filename.endswith('2.txt'):
          with open(filename, 'r') as f:
              numbers_str = f.read()
          numbers_list = numbers_str.split()
          numbers_int = list(map(float, numbers_list))
          actual += numbers_int
  prediction = [round(x, 0) for x in prediction]
  actual = [round(x, 0) for x in actual]

  accuracy = accuracy_score(actual, prediction)
  accuracies_for_2_laplacian.append(accuracy)
  print(f'Accuracy for 2-laplacian: {accuracy}')

  max_accuracy0 = max(accuracies_for_0_laplacian)
  max_index0 = accuracies_for_0_laplacian.index(max_accuracy0)
  print(f"The maximum accuracy for 0 laplacian is: {max_accuracy0} and its index is: {max_index0} with coefficient {random_numbers[max_index0]}")

  max_accuracy1 = max(accuracies_for_1_laplacian)
  max_index1 = accuracies_for_1_laplacian.index(max_accuracy1)
  print(f"The maximum accuracy for 1 laplacian is: {max_accuracy1} and its index is: {max_index1} with coefficient {random_numbers[max_index1]}")

  max_accuracy2 = max(accuracies_for_2_laplacian)
  max_index2 = accuracies_for_2_laplacian.index(max_accuracy2)
  print(f"The maximum accuracy for 2 laplacian is: {max_accuracy2} and its index is: {max_index2} with coefficient {random_numbers[max_index2]}")

  Iteration+=1
# Out:
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5060653360921712
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6512356935014549
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6512356935014549 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.359234174314116
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6475974781765277
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6512356935014549 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.7279193303638871
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6508971871968963
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6512356935014549 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.788759754414407
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6588622696411252
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6588622696411252 and its index is: 3 with coefficient 0.788759754414407
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.6378263643746973
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6380203685741999
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6588622696411252 and its index is: 3 with coefficient 0.788759754414407
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.19317982908021525
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6649068865179437
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6649068865179437 and its index is: 5 with coefficient 0.19317982908021525
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5165456741296539
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6785043646944714
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6785043646944714 and its index is: 6 with coefficient 0.5165456741296539
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.32023349153720393
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6842036857419981
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6842036857419981 and its index is: 7 with coefficient 0.32023349153720393
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.7943971403084205
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6778991270611058
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6842036857419981 and its index is: 7 with coefficient 0.32023349153720393
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5411825289914485
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6476828322017458
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6842036857419981 and its index is: 7 with coefficient 0.32023349153720393
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.1894325363461804
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6357487875848691
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6842036857419981 and its index is: 7 with coefficient 0.32023349153720393
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.2653032344249452
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6805819592628516
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6842036857419981 and its index is: 7 with coefficient 0.32023349153720393
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.03180811187994437
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6948952473326867
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5051789758305242
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6821901066925316
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5379236511958612
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6784413191076625
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5645252599675288
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6840358874878758
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.15209776795726948
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6841125121241514
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.17063517379441917
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6773045586808923
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.6701400460852986
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6807681862269641
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5244245657626685
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6807759456838022
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.8918678279629403
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6803928225024248
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Traceback (most recent call last):
#   File "/content/simplicial_neural_networks/./experiments/impute_citations.py", line 202, in <module>
#     main()
#   File "/content/simplicial_neural_networks/./experiments/impute_citations.py", line 98, in main
#     Ls =[scnn.scnn.coo2tensor(scnn.chebyshev.normalize(laplacians[i],half_interval=True)) for i in range(topdim+1)] #####scnn.chebyshev.normalize ?
#   File "/content/simplicial_neural_networks/./experiments/impute_citations.py", line 98, in <listcomp>
#     Ls =[scnn.scnn.coo2tensor(scnn.chebyshev.normalize(laplacians[i],half_interval=True)) for i in range(topdim+1)] #####scnn.chebyshev.normalize ?
#   File "/content/simplicial_neural_networks/./scnn/chebyshev.py", line 10, in normalize
#     topeig = spl.eigsh(L, k=1, which="LM", return_eigenvectors = False)[0]
#   File "/usr/local/lib/python3.10/dist-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py", line 1697, in eigsh
#     params.iterate()
#   File "/usr/local/lib/python3.10/dist-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py", line 573, in iterate
#     raise ArpackError(self.info, infodict=self.iterate_infodict)
# scipy.sparse.linalg._eigen.arpack.arpack.ArpackError: ARPACK error 3: No shifts could be applied during a cycle of the Implicitly restarted Arnoldi iteration. One possibility is to increase the size of NCV relative to NEV.
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5068496501851958
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6803928225024248
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.6699199126532781
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6803928225024248
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6756163549369291 and its index is: 0 with coefficient 0.5060653360921712
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.09934507678758453
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6803928225024248
# Accuracy for 2-laplacian: 0.6759786863853849
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6759786863853849 and its index is: 23 with coefficient 0.09934507678758453
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks/data/s2_3_collaboration_complex
# /content/simplicial_neural_networks
# Parameter counts:
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# 150
# 30
# 4500
# 30
# 150
# 1
# Total number of parameters: 14583
# [0.6988636363636364, 0.6994572591587517, 0.6998477929984779]
# /content/simplicial_neural_networks/experiments/output
# We set this random number:  0.5312824612369326
# Accuracy for 0-laplacian: 0.6437439024390244
# Accuracy for 1-laplacian: 0.6807681862269641
# Accuracy for 2-laplacian: 0.6756163549369291
# The maximum accuracy for 0 laplacian is: 0.6437439024390244 and its index is: 0 with coefficient 0.5060653360921712
# The maximum accuracy for 1 laplacian is: 0.6948952473326867 and its index is: 12 with coefficient 0.03180811187994437
# The maximum accuracy for 2 laplacian is: 0.6759786863853849 and its index is: 23 with coefficient 0.09934507678758453

# %%
# 0-laplacian accuracies
for i in range(len(accuracies_for_0_laplacian)):
  print("0-laplacian accuracy: ",accuracies_for_0_laplacian[i],"for random number: ",random_numbers[i])
# Out:
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.5060653360921712
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.359234174314116
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.7279193303638871
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.788759754414407
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.6378263643746973
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.19317982908021525
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.5165456741296539
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.32023349153720393
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.7943971403084205
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.5411825289914485
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.1894325363461804
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.2653032344249452
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.03180811187994437
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.5051789758305242
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.5379236511958612
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.5645252599675288
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.15209776795726948
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.17063517379441917
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.6701400460852986
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.5244245657626685
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.8918678279629403
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.5068496501851958
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.6699199126532781
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.09934507678758453
# 0-laplacian accuracy:  0.6437439024390244 for random number:  0.5312824612369326

# %%
# 1-laplacian accuracies
for i in range(len(accuracies_for_1_laplacian)):
  print("1-laplacian accuracy: ",accuracies_for_1_laplacian[i],"for random number: ",random_numbers[i])
# Out:
# 1-laplacian accuracy:  0.6512356935014549 for random number:  0.5060653360921712
# 1-laplacian accuracy:  0.6475974781765277 for random number:  0.359234174314116
# 1-laplacian accuracy:  0.6508971871968963 for random number:  0.7279193303638871
# 1-laplacian accuracy:  0.6588622696411252 for random number:  0.788759754414407
# 1-laplacian accuracy:  0.6380203685741999 for random number:  0.6378263643746973
# 1-laplacian accuracy:  0.6649068865179437 for random number:  0.19317982908021525
# 1-laplacian accuracy:  0.6785043646944714 for random number:  0.5165456741296539
# 1-laplacian accuracy:  0.6842036857419981 for random number:  0.32023349153720393
# 1-laplacian accuracy:  0.6778991270611058 for random number:  0.7943971403084205
# 1-laplacian accuracy:  0.6476828322017458 for random number:  0.5411825289914485
# 1-laplacian accuracy:  0.6357487875848691 for random number:  0.1894325363461804
# 1-laplacian accuracy:  0.6805819592628516 for random number:  0.2653032344249452
# 1-laplacian accuracy:  0.6948952473326867 for random number:  0.03180811187994437
# 1-laplacian accuracy:  0.6821901066925316 for random number:  0.5051789758305242
# 1-laplacian accuracy:  0.6784413191076625 for random number:  0.5379236511958612
# 1-laplacian accuracy:  0.6840358874878758 for random number:  0.5645252599675288
# 1-laplacian accuracy:  0.6841125121241514 for random number:  0.15209776795726948
# 1-laplacian accuracy:  0.6773045586808923 for random number:  0.17063517379441917
# 1-laplacian accuracy:  0.6807681862269641 for random number:  0.6701400460852986
# 1-laplacian accuracy:  0.6807759456838022 for random number:  0.5244245657626685
# 1-laplacian accuracy:  0.6803928225024248 for random number:  0.8918678279629403
# 1-laplacian accuracy:  0.6803928225024248 for random number:  0.5068496501851958
# 1-laplacian accuracy:  0.6803928225024248 for random number:  0.6699199126532781
# 1-laplacian accuracy:  0.6803928225024248 for random number:  0.09934507678758453
# 1-laplacian accuracy:  0.6807681862269641 for random number:  0.5312824612369326

# %%
# 2-laplacian accuracies
for i in range(len(accuracies_for_2_laplacian)):
  print("2-laplacian accuracy: ",accuracies_for_2_laplacian[i],"for random number: ",random_numbers[i])
# Out:
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.5060653360921712
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.359234174314116
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.7279193303638871
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.788759754414407
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.6378263643746973
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.19317982908021525
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.5165456741296539
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.32023349153720393
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.7943971403084205
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.5411825289914485
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.1894325363461804
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.2653032344249452
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.03180811187994437
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.5051789758305242
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.5379236511958612
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.5645252599675288
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.15209776795726948
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.17063517379441917
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.6701400460852986
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.5244245657626685
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.8918678279629403
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.5068496501851958
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.6699199126532781
# 2-laplacian accuracy:  0.6759786863853849 for random number:  0.09934507678758453
# 2-laplacian accuracy:  0.6756163549369291 for random number:  0.5312824612369326

# %%
print("Max accuracy we got: ",max_accuracy0,max_accuracy1,max_accuracy2)
# Out:
# Max accuracy we got:  0.6437439024390244 0.6948952473326867 0.6759786863853849
